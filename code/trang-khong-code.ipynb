# %% [markdown]
# # Standardized Test Analysis With SAT Data

# %% [markdown]
# ---
# # Part 1
#
# Part 1 requires knowledge of basic Python.
#
# ---

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# The digital SAT will be release in March 2024 for students in the United State. However, the numbers of students who took the SAT test was different from each states and the rate of students who participate in SAT test have changed each year. The purpose of this project is to explore the change of participation rate for the year 2018 and 2019 and identify states that have the SAT participation rate increased.

# %% [markdown]
# ### Contents:
# - [Background](#Background)
# - [Data Import & Cleaning](#Data-Import-and-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-Data)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %% [markdown]
# ## Background

# %% [markdown]
# The SAT is standardized tests that many colleges and universities in the United States require for their admissions process. This score is used along with other materials such as grade point average (GPA) and essay responses to determine whether or not a potential student will be accepted to the university.
#
# The SAT has two sections of the test: Evidence-Based Reading and Writing and Math ([*source*](https://www.princetonreview.com/college/sat-sections)). SAT have different score ranges and each colleges and universities have different score range for their admission ([*source*](https://prepmaven.com/blog/test-prep/average-sat-scores/#:~:text=As%20a%20whole%2C%20the%20average,1564%20for%20total%20SAT%20scores.)). You can read more about on their websites or additional outside sources (a quick Google search will help you understand the scores for [SAT](https://collegereadiness.collegeboard.org/sat) test)
#
# Standardized tests have long been a controversial topic for students, administrators, and legislators. Since the 1940's, an increasing number of colleges have been using scores from sudents' performances on tests like the SAT as a measure for college readiness and aptitude ([*source*](https://www.minotdailynews.com/news/local-news/2017/04/a-brief-history-of-the-sat-and-act/)). Supporters of these tests argue that these scores can be used as an objective measure to determine college admittance. Opponents of these tests claim that these tests are not accurate measures of students potential or ability and serve as an inequitable barrier to entry.
#
# The digital SAT is a new version of taking SAT test for students. In March 2023, the digital SAT was released for the international test center. The digital SAT will be apply for students in the United States in March 2024. Instead of taking SAT test with pencil and paper, students take the test on the computer with digital SAT version ([*source*](https://newsroom.collegeboard.org/sat-program-results-show-increased-participation-class-2022)).

# %% [markdown]
# ### Choose your Data
#
#
#
#
# * [`sat_2018.csv`](./data/sat_2018.csv): 2018 SAT Scores by State
# * [`sat_2019.csv`](./data/sat_2019.csv): 2019 SAT Scores by State
#
#  **Brief description of the contents for each dataset.**
#
#  There are fifth columns in each dataset:
#
#  * First column: name of state that have students participate in SAT test
#
#  * Second column: participation rate of students participated in SAT test
#
#  * Third column: average evidence-based reading and writing score
#
#  * Fourth column: average math score
#
#  * Fifth column: total average evidence-based reading and writing score and math score

# %% [markdown]
# ### Outside Research

# %% [markdown]
# The school year of 2019 had the highest number of students took the SAT test with more than 2.2 million students participated in the test. The participation rate in 2019 was increase 4% compare to the participation rate of 2018 ([*source*](https://newsroom.collegeboard.org/over-22-million-students-class-2019-took-sat-largest-group-ever)).

# %% [markdown]
# ### Coding Challenges
#
# 1. Manually calculate mean:
#
#     Write a function that takes in values and returns the mean of the values. Create a list of numbers that you test on your function to check to make sure your function works!
#
#     *Note*: Do not use any mean methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
# Code:
def calculate_mean(numbers):
    sum_num = 0
    length = 0
    
    for value in numbers:
        sum_num += value
        length += 1
    
    mean = sum_num / length
    
    return mean

# %% [markdown]
# 2. Manually calculate standard deviation:
#
#     The formula for standard deviation is below:
#
#     $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
#     Where $x_i$ represents each value in the dataset, $\mu$ represents the mean of all values in the dataset and $n$ represents the number of values in the dataset.
#
#     Write a function that takes in values and returns the standard deviation of the values using the formula above. Hint: use the function you wrote above to calculate the mean! Use the list of numbers you created above to test on your function.
#
#     *Note*: Do not use any standard deviation methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
# Code:
def calculate_standard_deviation(numbers):
    mean = calculate_mean(numbers)
    
    diff_sum = 0
    
    # i = i + 1 => i += 1
    
    for number in numbers:
        diff_sum += (number - mean) ** 2
    
        return (diff_sum/len(numbers)) ** 0.5

# %% [markdown]
# 3. Data cleaning function:
#
#     Write a function that takes in a string that is a number and a percent symbol (ex. '50%', '30.5%', etc.) and converts this to a float that is the decimal approximation of the percent. For example, inputting '50%' in your function should return 0.5, '30.5%' should return 0.305, etc. Make sure to test your function to make sure it works!
#
# You will use these functions later on in the project!

# %%
# Code:
def string_to_float(n):
    return float(n.strip('%'))/100

#https://stackoverflow.com/questions/12432663/what-is-a-clean-way-to-convert-a-string-percent-to-a-float

# %%
string_to_float('30.5%')
# Out:
# 0.305

# %% [markdown]
# ---
# # Part 2
#
# Part 2 requires knowledge of Pandas, EDA, data cleaning, and data visualization.
#
# ---

# %% [markdown]
# *All libraries used should be added here*

# %% [markdown]
# ## Data Import and Cleaning

# %% [markdown]
# ### Data Import & Cleaning

# %%
# Imports:
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sat_2018 = pd.read_csv('../data/sat_2018.csv')
sat_2018.head()
# Out:
#         State Participation  Evidence-Based Reading and Writing  Math  Total
# 0     Alabama            6%                                 595   571   1166
# 1      Alaska           43%                                 562   544   1106
# 2     Arizona           29%                                 577   572   1149
# 3    Arkansas            5%                                 592   576   1169
# 4  California           60%                                 540   536   1076

# %%
sat_2019 = pd.read_csv('../data/sat_2019.csv')
sat_2019.head()
# Out:
#         State Participation Rate  EBRW  Math  Total
# 0     Alabama                 7%   583   560   1143
# 1      Alaska                41%   556   541   1097
# 2     Arizona                31%   569   565   1134
# 3    Arkansas                 6%   582   559   1141
# 4  California                63%   534   531   1065

# %%
sat_2018.columns = sat_2018.columns.str.lower()
sat_2018.head()
# Out:
#         state participation  evidence-based reading and writing  math  total
# 0     Alabama            6%                                 595   571   1166
# 1      Alaska           43%                                 562   544   1106
# 2     Arizona           29%                                 577   572   1149
# 3    Arkansas            5%                                 592   576   1169
# 4  California           60%                                 540   536   1076

# %%
sat_2019.columns = sat_2019.columns.str.lower()
sat_2019.head()
# Out:
#         state participation rate  ebrw  math  total
# 0     Alabama                 7%   583   560   1143
# 1      Alaska                41%   556   541   1097
# 2     Arizona                31%   569   565   1134
# 3    Arkansas                 6%   582   559   1141
# 4  California                63%   534   531   1065

# %%
sat_2018['participation_rate'] = sat_2018['participation'].apply(string_to_float)
sat_2018.head()
# Out:
#         state participation  evidence-based reading and writing  math  total  \
# 0     Alabama            6%                                 595   571   1166
# 1      Alaska           43%                                 562   544   1106
# 2     Arizona           29%                                 577   572   1149
# 3    Arkansas            5%                                 592   576   1169
# 4  California           60%                                 540   536   1076
#
#    participation_rate
# 0                0.06
# 1                0.43
# 2                0.29
# 3                0.05
# 4                0.60

# %%
sat_2019_update = sat_2019.drop([39,47])

# %%
sat_2019_update['participation_rate'] = sat_2019_update['participation rate'].apply(string_to_float)
sat_2019.head()
# Out:
#         state participation rate  ebrw  math  total
# 0     Alabama                 7%   583   560   1143
# 1      Alaska                41%   556   541   1097
# 2     Arizona                31%   569   565   1134
# 3    Arkansas                 6%   582   559   1141
# 4  California                63%   534   531   1065

# %%
sat_2019_update.rename(columns = {'participation rate':'participation'}, inplace = True)

# %%
sat_2019_update.rename(columns = {'ebrw':'evidence_based_reading_writing'}, inplace = True)

# %%
sat_2019_update.head()
# Out:
#         state participation  evidence_based_reading_writing  math  total  \
# 0     Alabama            7%                             583   560   1143
# 1      Alaska           41%                             556   541   1097
# 2     Arizona           31%                             569   565   1134
# 3    Arkansas            6%                             582   559   1141
# 4  California           63%                             534   531   1065
#
#    participation_rate
# 0                0.07
# 1                0.41
# 2                0.31
# 3                0.06
# 4                0.63

# %%
sat_2018.rename(columns = {'evidence-based reading and writing':'evidence_based_reading_writing'}, inplace = True)

# %%
sat_2018.head()
# Out:
#         state participation  evidence_based_reading_writing  math  total  \
# 0     Alabama            6%                             595   571   1166
# 1      Alaska           43%                             562   544   1106
# 2     Arizona           29%                             577   572   1149
# 3    Arkansas            5%                             592   576   1169
# 4  California           60%                             540   536   1076
#
#    participation_rate
# 0                0.06
# 1                0.43
# 2                0.29
# 3                0.05
# 4                0.60

# %%
sat_2019_update2 = sat_2019_update.reset_index(drop=True)

# %%
# Code:

# %% [markdown]
# ### Data Dictionary
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |state|object|SAT_2018 and SAT_2019|List of state that participate in SAT test|
# |participation|object|SAT_2018 and SAT_2019|Percentage of students participated in SAT test|
# |evidence_based_reading_writing|integer|SAT_2018 and SAT_2019|Average evidence based reading writing score|
# |math|integer|SAT_2018 and SAT_2019|Average math score|
# |total|integer|SAT_2018 and SAT_2019|Total average of evidence based reading writing and math score|
# |particapation_rate|float|SAT_2018 and SAT_2019| Convert the percentage of student participated in SAT test to decimal (unit percent divided by 100)|

# %% [markdown]
# ## Exploratory Data Analysis

# %%
sat_2018_sd = {col.name: calculate_standard_deviation(col) for col in [sat_2018[i] for i in sat_2018.columns if (sat_2018[i].dtype == "int") or (sat_2018[i].dtype == "float") ]} #got help from TA for dictionary comprehension

# %%
sat_2018_sd
# Out:
# {'evidence_based_reading_writing': 4.384798616064187,
#  'math': 2.0674723593590008,
#  'total': 6.438542739305263,
#  'participation_rate': 0.055654269222054416}

# %%
sat_2019_update_sd = {col.name : calculate_standard_deviation(col) for col in [sat_2019_update[i] for i in sat_2019_update.columns if (sat_2019_update[i].dtype == "int") or (sat_2019_update[i].dtype == "float")]}
sat_2019_update_sd
# Out:
# {'evidence_based_reading_writing': 3.108072657097472,
#  'math': 1.0927675949865576,
#  'total': 4.189857663189702,
#  'participation_rate': 0.05889413294588393}

# %% [markdown]
# **The participation rate of sat_2018 and sat_2019 have lowest standard deviation, the participation rate values are close to the mean.**

# %%
# 10 states that have lowest participation rate in 2018

pr_2018_low = sat_2018.sort_values(by = 'participation_rate')[:10]
pr_2018_low
# Out:
#            state participation  evidence_based_reading_writing  math  total  \
# 34  North Dakota            2%                             640   643   1283
# 50       Wyoming            3%                             633   625   1257
# 41  South Dakota            3%                             622   618   1240
# 27      Nebraska            3%                             629   623   1252
# 49     Wisconsin            3%                             641   653   1294
# 24   Mississippi            3%                             630   606   1236
# 15          Iowa            3%                             634   631   1265
# 44          Utah            4%                             480   530   1010
# 23     Minnesota            4%                             643   655   1298
# 18     Louisiana            4%                             615   595   1210
#
#     participation_rate
# 34                0.02
# 50                0.03
# 41                0.03
# 27                0.03
# ...

# %%
#States that have the participation rate equal and less than 3% in 2018

sat_2018.loc[sat_2018['participation_rate']<=0.03, ['state','total','participation_rate']]
# Out:
#            state  total  participation_rate
# 15          Iowa   1265                0.03
# 24   Mississippi   1236                0.03
# 27      Nebraska   1252                0.03
# 34  North Dakota   1283                0.02
# 41  South Dakota   1240                0.03
# 49     Wisconsin   1294                0.03
# 50       Wyoming   1257                0.03

# %%
# 10 states that have lowest participation rate in 2019

pr_2019_low = sat_2019_update.sort_values(by = 'participation_rate')[:10]
pr_2019_low
# Out:
#            state participation  evidence_based_reading_writing  math  total  \
# 34  North Dakota            2%                             627   636   1263
# 52       Wyoming            3%                             623   615   1238
# 42  South Dakota            3%                             633   635   1268
# 27      Nebraska            3%                             628   631   1260
# 51     Wisconsin            3%                             635   648   1283
# 24   Mississippi            3%                             628   608   1237
# 15          Iowa            3%                             622   622   1244
# 45          Utah            4%                             614   615   1230
# 23     Minnesota            4%                             636   648   1284
# 17      Kentucky            4%                             620   612   1232
#
#     participation_rate
# 34                0.02
# 52                0.03
# 42                0.03
# 27                0.03
# ...

# %%
#States that have the participation rate equal and less than 3% in 2019

sat_2019_update.loc[sat_2019_update['participation_rate']<=0.03, ['state','total','participation_rate']]
# Out:
#            state  total  participation_rate
# 15          Iowa   1244                0.03
# 24   Mississippi   1237                0.03
# 27      Nebraska   1260                0.03
# 34  North Dakota   1263                0.02
# 42  South Dakota   1268                0.03
# 51     Wisconsin   1283                0.03
# 52       Wyoming   1238                0.03

# %% [markdown]
# **The five states that have lowest participation rate did not change from 2018 to 2019. North Dakota had the lowest participation rate in 2018 and 2019**

# %%
# 12 states that have highest participation rate in 2018

pr_2018_high=sat_2018.sort_values(by = 'participation_rate', ascending=False)[:12]
pr_2018_high
# Out:
#                    state participation  evidence_based_reading_writing  math  \
# 5               Colorado          100%                             519   506
# 6            Connecticut          100%                             535   519
# 7               Delaware          100%                             505   492
# 22              Michigan          100%                             511   499
# 12                 Idaho          100%                             508   493
# 19                 Maine           99%                             512   501
# 13              Illinois           99%                             513   506
# 39          Rhode Island           97%                             513   505
# 29         New Hampshire           96%                             535   528
# 8   District of Columbia           92%                             497   480
# 30            New Jersey           82%                             547   547
# ...

# %%
## 12 states that have highest participation rate in 2019

pr_2019_high = sat_2019_update.sort_values(by = 'participation_rate', ascending=False)[:12]
pr_2019_high
# Out:
#                    state participation  evidence_based_reading_writing  math  \
# 40          Rhode Island          100%                             503   492
# 13              Illinois          100%                             509   504
# 22              Michigan          100%                             507   496
# 5               Colorado          100%                             518   506
# 6            Connecticut          100%                             529   516
# 7               Delaware          100%                             499   486
# 9                Florida          100%                             516   483
# 12                 Idaho          100%                             505   488
# 19                 Maine           99%                             512   502
# 50         West Virginia           99%                             483   460
# 29         New Hampshire           95%                             533   526
# ...

# %%
#States that have more than 50% of the participation rate in 2018

sat_2018.loc[sat_2018['participation_rate']>0.5, ['state','total','participation_rate']]
# Out:
#                    state  total  participation_rate
# 4             California   1076                0.60
# 5               Colorado   1025                1.00
# 6            Connecticut   1053                1.00
# 7               Delaware    998                1.00
# 8   District of Columbia    977                0.92
# 9                Florida   1099                0.56
# 10               Georgia   1064                0.70
# 11                Hawaii   1010                0.56
# 12                 Idaho   1001                1.00
# 13              Illinois   1019                0.99
# 14               Indiana   1074                0.63
# 19                 Maine   1013                0.99
# 20              Maryland   1080                0.76
# 21         Massachusetts   1125                0.80
# 22              Michigan   1011                1.00
# 29         New Hampshire   1063                0.96
# 30            New Jersey   1094                0.82
# ...

# %%
#States that have more than 50% of the participation rate in 2019

sat_2019_update.loc[sat_2019_update['participation_rate']>0.5, ['state','total','participation_rate']]
# Out:
#                    state  total  participation_rate
# 4             California   1065                0.63
# 5               Colorado   1024                1.00
# 6            Connecticut   1046                1.00
# 7               Delaware    985                1.00
# 8   District of Columbia    975                0.94
# 9                Florida    999                1.00
# 10               Georgia   1058                0.71
# 11                Hawaii   1100                0.54
# 12                 Idaho    993                1.00
# 13              Illinois   1013                1.00
# 14               Indiana   1080                0.66
# 19                 Maine   1013                0.99
# 20              Maryland   1058                0.82
# 21         Massachusetts   1120                0.81
# 22              Michigan   1003                1.00
# 29         New Hampshire   1059                0.95
# 30            New Jersey   1090                0.82
# ...

# %% [markdown]
# **The participation rate increase in 2019, more students participates in SAT test. Five states that have 100% participation in 2018 but eight states have 100% participation in 2019.**

# %%
# 7 States have highest the total score in 2018

sat_2018.sort_values('total', ascending=False).head(7)
# Out:
#            state participation  evidence_based_reading_writing  math  total  \
# 23     Minnesota            4%                             643   655   1298
# 49     Wisconsin            3%                             641   653   1294
# 34  North Dakota            2%                             640   643   1283
# 15          Iowa            3%                             634   631   1265
# 16        Kansas            4%                             633   631   1265
# 25      Missouri            4%                             633   629   1262
# 50       Wyoming            3%                             633   625   1257
#
#     participation_rate
# 23                0.04
# 49                0.03
# 34                0.02
# 15                0.03
# 16                0.04
# 25                0.04
# 50                0.03

# %%
# 7 States have highest the total score in 2019

sat_2019_update.sort_values('total', ascending=False).head(7)
# Out:
#            state participation  evidence_based_reading_writing  math  total  \
# 23     Minnesota            4%                             636   648   1284
# 51     Wisconsin            3%                             635   648   1283
# 42  South Dakota            3%                             633   635   1268
# 34  North Dakota            2%                             627   636   1263
# 27      Nebraska            3%                             628   631   1260
# 15          Iowa            3%                             622   622   1244
# 16        Kansas            4%                             618   623   1241
#
#     participation_rate
# 23                0.04
# 51                0.03
# 42                0.03
# 34                0.02
# 27                0.03
# 15                0.03
# 16                0.04

# %% [markdown]
# **States that have lowest percent of participation have higher total scores.**

# %%
# 7 states that have lowest total score in 2018

sat_2018.sort_values('total').head(7)
# Out:
#                    state participation  evidence_based_reading_writing  math  \
# 8   District of Columbia           92%                             497   480
# 7               Delaware          100%                             505   492
# 48         West Virginia           28%                             513   486
# 12                 Idaho          100%                             508   493
# 44                  Utah            4%                             480   530
# 11                Hawaii           56%                             480   530
# 22              Michigan          100%                             511   499
#
#     total  participation_rate
# 8     977                0.92
# 7     998                1.00
# 48    999                0.28
# 12   1001                1.00
# 44   1010                0.04
# 11   1010                0.56
# 22   1011                1.00

# %%
# 7 states that have lowest total score in 2019

sat_2019_update.sort_values('total').head(7)
# Out:
#                    state participation  evidence_based_reading_writing  math  \
# 50         West Virginia           99%                             483   460
# 36              Oklahoma           22%                             490   472
# 8   District of Columbia           94%                             495   480
# 7               Delaware          100%                             499   486
# 12                 Idaho          100%                             505   488
# 40          Rhode Island          100%                             503   492
# 9                Florida          100%                             516   483
#
#     total  participation_rate
# 50    943                0.99
# 36    963                0.22
# 8     975                0.94
# 7     985                1.00
# 12    993                1.00
# 40    995                1.00
# 9     999                1.00

# %% [markdown]
# **States that have lower total score tend to have higher percent of participation.**

# %%
#Calculation mean of participation rate, total, evidence_base_reading_writing, and math in 2018

sat_2018[['participation_rate','total','evidence_based_reading_writing','math']].mean()
# Out:
# participation_rate                   0.457451
# total                             1120.019608
# evidence_based_reading_writing     563.686275
# math                               556.235294
# dtype: float64

# %%
#Calculation mean of participation rate, total, evidence_base_reading_writing, and math in 2019

sat_2019_update[['participation_rate','total','evidence_based_reading_writing','math']].mean()
# Out:
# participation_rate                   0.490588
# total                             1113.078431
# evidence_based_reading_writing     560.803922
# math                               552.196078
# dtype: float64

# %% [markdown]
# **The mean of the participation rate was increased around 4% from 2018 to 2019.
#
# **The mean of the total score was decreased from 2018 to 2019.**

# %%
#Calculation median of participation rate, total, evidence_base_reading_writing, and math in 2018

sat_2018[['participation_rate','total','evidence_based_reading_writing','math']].median()
# Out:
# participation_rate                   0.52
# total                             1098.00
# evidence_based_reading_writing     552.00
# math                               544.00
# dtype: float64

# %%
#Calculation median of participation rate, total, evidence_base_reading_writing, and math in 2019

sat_2019_update[['participation_rate','total','evidence_based_reading_writing','math']].median()
# Out:
# participation_rate                   0.54
# total                             1097.00
# evidence_based_reading_writing     550.00
# math                               546.00
# dtype: float64

# %% [markdown]
# **The median of the paticipation rate and total from 2018 to 2019 was similar.**

# %%
#https://blog.enterprisedna.co/pandas-drop-index/#:~:text=reset_index()%20methods.-,The%20.,it%20to%20the%20default%20RangeIndex.

# the different of participation rate between 2018 and 2019 to see which states had the participation increase.

sat_diff = sat_2019_update2['participation_rate'] - sat_2018['participation_rate']

# %% [markdown]
# **To-Do:** *Edit this cell with your findings on trends in the data (step 3 above).*

# %% [markdown]
# ## Visualize the Data

# %%
# Establish size of figure.
plt.figure(figsize = (10, 10))

# Get correlation of variables.
corr = sat_2018.corr()

# Set up mask to be "True" in the upper triangle.
mask = np.zeros_like(corr)
mask[np.triu_indices_from(mask)] = True

# Plot our correlation heatmap, while masking the upper triangle to be white.
sns.heatmap(corr, annot=True, mask = mask, cmap = 'mako', vmax = 1, vmin = -1);
# Out:
# /var/folders/mh/_rcy82jn02986q7q47fnf2mc0000gn/T/ipykernel_3368/2125726346.py:5: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = sat_2018.corr()

# %%
# Establish size of figure.
plt.figure(figsize = (10, 10))

# Get correlation of variables.
corr = sat_2019_update.corr()

# Set up mask to be "True" in the upper triangle.
mask = np.zeros_like(corr)
mask[np.triu_indices_from(mask)] = True

# Plot our correlation heatmap, while masking the upper triangle to be white.
sns.heatmap(corr, annot=True, mask = mask, cmap = 'mako', vmax = 1, vmin = -1);
# Out:
# /var/folders/mh/_rcy82jn02986q7q47fnf2mc0000gn/T/ipykernel_3368/2400464300.py:5: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = sat_2019_update.corr()

# %% [markdown]
# Both Seaborn's heatmap above show the correlation between evidence_based_reading_writting, math, total and participation_rate. The particapation_rate have lower

# %%
#size
plt.figure(figsize = (15, 5))

# bar chat
plt.bar(sat_2018['state'], sat_2018['participation_rate'])

# create a descriptive title
plt.title("The Participation Rate of SAT Test in 2018", fontsize = 20)

# rotate text on x asix
plt.xticks(rotation = 90)

# add axis labels

plt.xlabel("State")
plt.ylabel("Participation Rate");

# %%
#size
plt.figure(figsize = (15, 5))

# bar chat
plt.bar(sat_2019_update['state'], sat_2019_update['participation_rate'])

# create a descriptive title
plt.title("The Participation Rate of SAT Test in 2019", fontsize = 20)

# rotate text on x asix
plt.xticks(rotation = 90)

# add axis labels

plt.xlabel("State")
plt.ylabel("Participation Rate");

# %%
#size
plt.figure(figsize = (15, 5))

# bar chat
plt.bar(sat_2018['state'], sat_2018['total'])

# create a descriptive title
plt.title("The Total Score of SAT test in 2018", fontsize = 20)

# rotate text on x asix
plt.xticks(rotation = 90)

# add axis labels

plt.xlabel("State")
plt.ylabel("Total Score");

# %%
#size
plt.figure(figsize = (15, 5))

# bar chat
plt.bar(sat_2019_update['state'], sat_2019_update['total'])

# create a descriptive title
plt.title("The Total Score of SAT test in 2019", fontsize = 20)

# rotate text on x asix
plt.xticks(rotation = 90)

# add axis labels

plt.xlabel("State")
plt.ylabel("Total Score");

# %%
#size
plt.figure(figsize = (15, 5))

# bar chat
plt.bar(pr_2018_low['state'], pr_2018_low['participation_rate'])

# create a descriptive title
plt.title("Top 10 States with Lowest Participation Rate of SAT Test in 2018", fontsize = 20)

# rotate text on x asix
plt.xticks(rotation = 45)

# add axis labels

plt.xlabel("State")
plt.ylabel("Participation Rate (unit percent divided by 100)");

# %%
#size
plt.figure(figsize = (15, 5))

# bar chat
plt.bar(pr_2019_low['state'], pr_2019_low['participation_rate'])

# create a descriptive title
plt.title("Top 10 States with Lowest Participation Rate of SAT Test in 2019", fontsize = 20)

# rotate text on x asix
plt.xticks(rotation = 45)

# add axis labels

plt.xlabel("State")
plt.ylabel("Participation Rate (unit percent divided by 100)");

# %%
#size
plt.figure(figsize = (15, 5))

# bar chat
plt.bar(pr_2018_high['state'], pr_2018_high['participation_rate'])

# create a descriptive title
plt.title("Top 12 States have Highest Participation Rate of SAT Test in 2018", fontsize = 20)
# rotate text on x asix
plt.xticks(rotation = 75)

# add axis labels

plt.xlabel("State")
plt.ylabel("Participation Rate");

# %%
#size
plt.figure(figsize = (15, 5))

# bar chat
plt.bar(pr_2019_high['state'], pr_2019_high['participation_rate'])

# create a descriptive title
plt.title("Top 12 States have Highest Participation Rate of SAT Test in 2019", fontsize = 10)

# rotate text on x asix
plt.xticks(rotation = 75)

# add axis labels

plt.xlabel("State")
plt.ylabel("Participation Rate");

# %%
# Size
plt.figure(figsize = (15, 5))

# Plot it
plt.hist(sat_2018['participation_rate'], bins = 15)

# Create a descriptive title
plt.title("Distribution of Participation Rate in SAT Test 2018");

# %%
# Size
plt.figure(figsize = (15,5))

# Plot it
plt.hist(sat_2019_update['participation_rate'], bins = 15)

# Create a descriptive title
plt.title("Distribution of Participation Rate in SAT Test 2019");

# %%
#size
plt.figure(figsize = (15, 7))

# bar chat
plt.bar(sat_2018['state'], sat_diff)

# create a descriptive title
plt.title("The Differential of Participation Rate between 2018 and 2019", fontsize = 20)

# rotate text on x asix
plt.xticks(rotation = 90)

# add axis labels

plt.xlabel("State")
plt.ylabel("Participation Rate");

# %% [markdown]
# ## Conclusions

# %% [markdown]
# * The participation rate of SAT test was increased almost 4% from 2018 to 2019.
# * From 2018 to 2019, 23 states that had the SAT test participation rate increase.
# * West Virginia was the state that have highest increment rate. The participation rate of West Virginia was increased 71% from 2018 to 2019 (28% in 2018 and 99% in 2019).
# * Following by West Virginia, Florida had the participation rate increase from 56% (in 2018) to 100% (in 2019) which is 44% of increment rate.
# * South Carolina and Oklahoma also have the SAT test participation rate increase above 10%.
